# %%
import pandas as pd
import numpy as np

# %%
btc_pred = pd.read_csv('/Users/brunogama/Desktop/Final_Project/prediction_btc.csv')
eth_pred = pd.read_csv('/Users/brunogama/Desktop/Final_Project/prediction_eth.csv')
ada_pred = pd.read_csv('/Users/brunogama/Desktop/Final_Project/prediction_ada.csv')
dgc_pred = pd.read_csv('/Users/brunogama/Desktop/Final_Project/prediction_dgc.csv')

# %%
btc_pred
# Out:
#             Date          Open          High           Low         Close  \
# 0     2017-01-01    963.658020   1003.080017    958.698975    998.325012
# 1     2017-01-02    998.617004   1031.390015    996.702026   1021.750000
# 2     2017-01-03   1021.599976   1044.079956   1021.599976   1043.839966
# 3     2017-01-04   1044.400024   1159.420044   1044.400024   1154.729980
# 4     2017-01-05   1156.729980   1191.099976    910.416992   1013.380005
# ...          ...           ...           ...           ...           ...
# 1980  2022-06-04  29706.138672  29930.564453  29500.005859  29832.914062
# 1981  2022-06-05  29835.117188  30117.744141  29574.449219  29906.662109
# 1982  2022-06-06  29910.283203  31693.291016  29894.187500  31370.671875
# 1983  2022-06-07  31371.742188  31489.683594  29311.683594  31155.478516
# 1984  2022-06-08  31151.480469  31253.691406  29944.404297  30214.355469
#
#          Adj Close       Volume    Prediction
# ...

# %%
btc = btc_pred.assign(Name= 'BTC')
btc
# Out:
#             Date          Open          High           Low         Close  \
# 0     2017-01-01    963.658020   1003.080017    958.698975    998.325012
# 1     2017-01-02    998.617004   1031.390015    996.702026   1021.750000
# 2     2017-01-03   1021.599976   1044.079956   1021.599976   1043.839966
# 3     2017-01-04   1044.400024   1159.420044   1044.400024   1154.729980
# 4     2017-01-05   1156.729980   1191.099976    910.416992   1013.380005
# ...          ...           ...           ...           ...           ...
# 1980  2022-06-04  29706.138672  29930.564453  29500.005859  29832.914062
# 1981  2022-06-05  29835.117188  30117.744141  29574.449219  29906.662109
# 1982  2022-06-06  29910.283203  31693.291016  29894.187500  31370.671875
# 1983  2022-06-07  31371.742188  31489.683594  29311.683594  31155.478516
# 1984  2022-06-08  31151.480469  31253.691406  29944.404297  30214.355469
#
#          Adj Close       Volume    Prediction Name
# ...

# %%
eth_pred
# Out:
#             Date         Open         High          Low        Close  \
# 0     2017-11-09   308.644989   329.451996   307.056000   320.884003
# 1     2017-11-10   320.670990   324.717987   294.541992   299.252991
# 2     2017-11-11   298.585999   319.453003   298.191986   314.681000
# 3     2017-11-12   314.690002   319.153015   298.513000   307.907990
# 4     2017-11-13   307.024994   328.415009   307.024994   316.716003
# ...          ...          ...          ...          ...          ...
# 1668  2022-06-04  1775.220825  1810.299683  1751.533325  1801.609497
# 1669  2022-06-05  1801.818970  1825.859619  1777.133301  1805.204956
# 1670  2022-06-06  1805.635986  1915.030518  1804.990234  1859.289673
# 1671  2022-06-07  1859.333740  1862.914917  1729.413574  1814.048340
# 1672  2022-06-08  1814.100708  1830.676025  1770.231201  1793.572266
#
#         Adj Close       Volume   Prediction
# 0      320.884003    893249984   473.502014
# 1      299.252991    885985984   441.721008
# ...

# %%
eth = eth_pred.assign(Name= 'ETH')
eth
# Out:
#             Date         Open         High          Low        Close  \
# 0     2017-11-09   308.644989   329.451996   307.056000   320.884003
# 1     2017-11-10   320.670990   324.717987   294.541992   299.252991
# 2     2017-11-11   298.585999   319.453003   298.191986   314.681000
# 3     2017-11-12   314.690002   319.153015   298.513000   307.907990
# 4     2017-11-13   307.024994   328.415009   307.024994   316.716003
# ...          ...          ...          ...          ...          ...
# 1668  2022-06-04  1775.220825  1810.299683  1751.533325  1801.609497
# 1669  2022-06-05  1801.818970  1825.859619  1777.133301  1805.204956
# 1670  2022-06-06  1805.635986  1915.030518  1804.990234  1859.289673
# 1671  2022-06-07  1859.333740  1862.914917  1729.413574  1814.048340
# 1672  2022-06-08  1814.100708  1830.676025  1770.231201  1793.572266
#
#         Adj Close       Volume   Prediction Name
# 0      320.884003    893249984   473.502014  ETH
# ...

# %%
ada = ada_pred.assign(Name= 'ADA')
ada
# Out:
#             Date      Open      High       Low     Close  Adj Close  \
# 0     2017-11-09  0.025160  0.035060  0.025006  0.032053   0.032053
# 1     2017-11-10  0.032219  0.033348  0.026451  0.027119   0.027119
# 2     2017-11-11  0.026891  0.029659  0.025684  0.027437   0.027437
# 3     2017-11-12  0.027480  0.027952  0.022591  0.023977   0.023977
# 4     2017-11-13  0.024364  0.026300  0.023495  0.025808   0.025808
# ...          ...       ...       ...       ...       ...        ...
# 1668  2022-06-04  0.559957  0.570570  0.548088  0.566069   0.566069
# 1669  2022-06-05  0.566091  0.579553  0.556398  0.567090   0.567090
# 1670  2022-06-06  0.567207  0.643452  0.566608  0.609328   0.609328
# 1671  2022-06-07  0.609340  0.641993  0.574847  0.615445   0.615445
# 1672  2022-06-08  0.615485  0.666099  0.610954  0.641614   0.641614
#
#           Volume  Prediction Name
# 0       18716200    0.119609  ADA
# 1        6766780    0.110281  ADA
# 2        5532220    0.121383  ADA
# ...

# %%
ada_pred
# Out:
#             Date      Open      High       Low     Close  Adj Close  \
# 0     2017-11-09  0.025160  0.035060  0.025006  0.032053   0.032053
# 1     2017-11-10  0.032219  0.033348  0.026451  0.027119   0.027119
# 2     2017-11-11  0.026891  0.029659  0.025684  0.027437   0.027437
# 3     2017-11-12  0.027480  0.027952  0.022591  0.023977   0.023977
# 4     2017-11-13  0.024364  0.026300  0.023495  0.025808   0.025808
# ...          ...       ...       ...       ...       ...        ...
# 1668  2022-06-04  0.559957  0.570570  0.548088  0.566069   0.566069
# 1669  2022-06-05  0.566091  0.579553  0.556398  0.567090   0.567090
# 1670  2022-06-06  0.567207  0.643452  0.566608  0.609328   0.609328
# 1671  2022-06-07  0.609340  0.641993  0.574847  0.615445   0.615445
# 1672  2022-06-08  0.615485  0.666099  0.610954  0.641614   0.641614
#
#           Volume  Prediction
# 0       18716200    0.119609
# 1        6766780    0.110281
# 2        5532220    0.121383
# 3        7280250    0.133891
# ...

# %%
dgc = dgc_pred.assign(Name= 'DGC')
dgc
# Out:
#             Date      Open      High       Low     Close  Adj Close  \
# 0     2017-11-09  0.001207  0.001415  0.001181  0.001415   0.001415
# 1     2017-11-10  0.001421  0.001431  0.001125  0.001163   0.001163
# 2     2017-11-11  0.001146  0.001257  0.001141  0.001201   0.001201
# 3     2017-11-12  0.001189  0.001210  0.001002  0.001038   0.001038
# 4     2017-11-13  0.001046  0.001212  0.001019  0.001211   0.001211
# ...          ...       ...       ...       ...       ...        ...
# 1668  2022-06-04  0.080454  0.082337  0.079727  0.081777   0.081777
# 1669  2022-06-05  0.081776  0.082138  0.080836  0.081229   0.081229
# 1670  2022-06-06  0.081225  0.084559  0.081126  0.082530   0.082530
# 1671  2022-06-07  0.082530  0.082530  0.078332  0.080513   0.080513
# 1672  2022-06-08  0.080492  0.081420  0.079156  0.079439   0.079439
#
#          Volume  Prediction Name
# 0       6259550    0.002617  DGC
# 1       4246520    0.002547  DGC
# 2       2231080    0.002798  DGC
# ...

# %%
dgc_pred
# Out:
#             Date      Open      High       Low     Close  Adj Close  \
# 0     2017-11-09  0.001207  0.001415  0.001181  0.001415   0.001415
# 1     2017-11-10  0.001421  0.001431  0.001125  0.001163   0.001163
# 2     2017-11-11  0.001146  0.001257  0.001141  0.001201   0.001201
# 3     2017-11-12  0.001189  0.001210  0.001002  0.001038   0.001038
# 4     2017-11-13  0.001046  0.001212  0.001019  0.001211   0.001211
# ...          ...       ...       ...       ...       ...        ...
# 1668  2022-06-04  0.080454  0.082337  0.079727  0.081777   0.081777
# 1669  2022-06-05  0.081776  0.082138  0.080836  0.081229   0.081229
# 1670  2022-06-06  0.081225  0.084559  0.081126  0.082530   0.082530
# 1671  2022-06-07  0.082530  0.082530  0.078332  0.080513   0.080513
# 1672  2022-06-08  0.080492  0.081420  0.079156  0.079439   0.079439
#
#          Volume  Prediction
# 0       6259550    0.002617
# 1       4246520    0.002547
# 2       2231080    0.002798
# 3       3288960    0.003304
# ...

# %%
all_predictions = pd.concat([btc, eth, ada, dgc]).reset_index()
all_predictions
# Out:
#       index        Date         Open         High          Low        Close  \
# 0         0  2017-01-01   963.658020  1003.080017   958.698975   998.325012
# 1         1  2017-01-02   998.617004  1031.390015   996.702026  1021.750000
# 2         2  2017-01-03  1021.599976  1044.079956  1021.599976  1043.839966
# 3         3  2017-01-04  1044.400024  1159.420044  1044.400024  1154.729980
# 4         4  2017-01-05  1156.729980  1191.099976   910.416992  1013.380005
# ...     ...         ...          ...          ...          ...          ...
# 6999   1668  2022-06-04     0.080454     0.082337     0.079727     0.081777
# 7000   1669  2022-06-05     0.081776     0.082138     0.080836     0.081229
# 7001   1670  2022-06-06     0.081225     0.084559     0.081126     0.082530
# 7002   1671  2022-06-07     0.082530     0.082530     0.078332     0.080513
# 7003   1672  2022-06-08     0.080492     0.081420     0.079156     0.079439
#
#         Adj Close     Volume   Prediction Name
# ...

# %%
all_predictions.to_csv('all_predictions.csv')
